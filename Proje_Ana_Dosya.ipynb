# %%
# Gerekli olabilecek kütüphaneleri importluyorum.
import numpy as np
import pandas as pd
import time

# %%
# Excel dosyasını okutarak illerin "Data Framelerini" oluşturacağım. 
# İndeksleme işlemi yaparken tabloları kolay bulabilmek adına data frameleri alfabetik sıraya göre oluşturuyorum.

# %% [markdown]
# **ADANA**

# %%
df_adana= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Adana")
df_adana
# Out:
#        ADANA  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  32                  17            0.19  \
# 1       Salı                  25                  15            0.75
# 2   Çarşamba                  24                  14            0.71
# 3   Perşembe                  25                  15            0.77
# 4       Cuma                  27                  15            0.24
# 5  Cumartesi                  28                  16            0.21
# 6      Pazar                  29                  16            0.19
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     21 km/h  PARÇALI BULUTLU
# 1     22 km/h  SAĞANAK YAĞIŞLI
# 2     24 km/h  SAĞANAK YAĞIŞLI
# 3     20 km/h  SAĞANAK YAĞIŞLI
# 4     20 km/h  PARÇALI BULUTLU
# 5     13 km/h  PARÇALI BULUTLU
# 6     16 km/h  PARÇALI BULUTLU

# %%
df_adana.iloc[:6,4]
# Out:
# 0    21 km/h
# 1    22 km/h
# 2    24 km/h
# 3    20 km/h
# 4    20 km/h
# 5    13 km/h
# Name: Rüzgar Hızı, dtype: object

# %% [markdown]
# **ANKARA**

# %%
df_ankara= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Ankara")
df_ankara
# Out:
#       ANKARA  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  23                  13            0.19  \
# 1       Salı                  23                  11            0.82
# 2   Çarşamba                  17                   8            0.61
# 3   Perşembe                  19                   6            0.10
# 4       Cuma                  18                   7            0.08
# 5  Cumartesi                  18                   7            0.21
# 6      Pazar                  20                   8            0.24
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     11 km/h          BULUTLU
# 1     11 km/h         YAĞMURLU
# 2     11 km/h         YAĞMURLU
# 3      7 km/h  PARÇALI BULUTLU
# 4      8 km/h  PARÇALI BULUTLU
# 5     21 km/h  PARÇALI BULUTLU
# 6     24 km/h          BULUTLU

# %% [markdown]
# **ANTALYA**

# %%
df_antalya= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Antalya")
df_antalya
# Out:
#      ANTALYA  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  18                  16            0.98  \
# 1       Salı                  21                  15            0.79
# 2   Çarşamba                  24                  16            0.12
# 3   Perşembe                  23                  16            0.38
# 4       Cuma                  22                  16            0.72
# 5  Cumartesi                  23                  17            0.35
# 6      Pazar                  24                  17            0.24
#
#   Rüzgar Hızı  Beklenen Hadise
# 0      8 km/h  SAĞANAK YAĞIŞLI
# 1      6 km/h  SAĞANAK YAĞIŞLI
# 2      7 km/h          GÜNEŞLİ
# 3      9 km/h         YAĞMURLU
# 4      7 km/h         YAĞMURLU
# 5      8 km/h         YAĞMURLU
# 6      8 km/h          GÜNEŞLİ

# %% [markdown]
# **AYDIN**

# %%
df_aydın= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Aydın")
df_aydın
# Out:
#        AYDIN  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  22                  11            0.90  \
# 1       Salı                  25                  11            0.12
# 2   Çarşamba                  28                  12            0.08
# 3   Perşembe                  27                  13            0.17
# 4       Cuma                  25                  12            0.49
# 5  Cumartesi                  26                  12            0.35
# 6      Pazar                  26                  12            0.08
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     11 km/h  SAĞANAK YAĞIŞLI
# 1     13 km/h          GÜNEŞLİ
# 2     13 km/h          GÜNEŞLİ
# 3     15 km/h  PARÇALI BULUTLU
# 4     13 km/h         YAĞMURLU
# 5     14 km/h         YAĞMURLU
# 6     16 km/h  PARÇALI BULUTLU

# %% [markdown]
# **BALIKESİR**

# %%
df_balıkesir= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Balıkesir")
df_balıkesir
# Out:
#    BALIKESİR  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  17                  10            0.70  \
# 1       Salı                  20                   7            0.49
# 2   Çarşamba                  21                   8            0.14
# 3   Perşembe                  19                   7            0.17
# 4       Cuma                  18                   7            0.56
# 5  Cumartesi                  20                   7            0.19
# 6      Pazar                  21                   9            0.24
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     26 km/h         YAĞMURLU
# 1     21 km/h         YAĞMURLU
# 2     19 km/h  PARÇALI BULUTLU
# 3     22 km/h  PARÇALI BULUTLU
# 4     19 km/h         YAĞMURLU
# 5     16 km/h  PARÇALI BULUTLU
# 6     14 km/h  PARÇALI BULUTLU

# %% [markdown]
# **BURSA**

# %%
df_bursa= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Bursa")
df_bursa
# Out:
#        BURSA  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  18                  10            0.83  \
# 1       Salı                  18                  10            0.76
# 2   Çarşamba                  18                   8            0.68
# 3   Perşembe                  20                   7            0.14
# 4       Cuma                  19                   8            0.10
# 5  Cumartesi                  19                   8            0.22
# 6      Pazar                  20                   9            0.22
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     14 km/h         YAĞMURLU
# 1     17 km/h         YAĞMURLU
# 2     14 km/h         YAĞMURLU
# 3     16 km/h  PARÇALI BULUTLU
# 4     16 km/h  PARÇALI BULUTLU
# 5     15 km/h  PARÇALI BULUTLU
# 6     13 km/h  PARÇALI BULUTLU

# %% [markdown]
# **DENİZLİ**

# %%
df_denizli= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Denizli")
df_denizli
# Out:
#      DENİZLİ  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  20                  11            0.97  \
# 1       Salı                  21                  10            0.33
# 2   Çarşamba                  24                  10            0.12
# 3   Perşembe                  24                  11            0.24
# 4       Cuma                  21                  10            0.71
# 5  Cumartesi                  24                  10            0.50
# 6      Pazar                  24                  12            0.24
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     10 km/h  SAĞANAK YAĞIŞLI
# 1     12 km/h         YAĞMURLU
# 2     10 km/h          GÜNEŞLİ
# 3     12 km/h  PARÇALI BULUTLU
# 4     10 km/h         YAĞMURLU
# 5     12 km/h         YAĞMURLU
# 6     12 km/h  PARÇALI BULUTLU

# %% [markdown]
# **DİYARBAKIR**

# %%
df_diyarbakır= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Diyarbakır")
df_diyarbakır
# Out:
#   DİYARBAKIR  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  27                  11            0.24  \
# 1       Salı                  24                   9            0.24
# 2   Çarşamba                  22                  10            0.74
# 3   Perşembe                  24                  10            0.59
# 4       Cuma                  25                  11            0.08
# 5  Cumartesi                  26                  12            0.15
# 6      Pazar                  27                  12            0.35
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     17 km/h  PARÇALI BULUTLU
# 1     17 km/h          GÜNEŞLİ
# 2     15 km/h  SAĞANAK YAĞIŞLI
# 3     12 km/h  SAĞANAK YAĞIŞLI
# 4     16 km/h  PARÇALI BULUTLU
# 5     16 km/h  PARÇALI BULUTLU
# 6     15 km/h  PARÇALI BULUTLU

# %% [markdown]
# **ERZURUM**

# %%
df_erzurum= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Erzurum")
df_erzurum
# Out:
#      ERZURUM  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  16                   6            0.64  \
# 1       Salı                  15                   4            0.77
# 2   Çarşamba                  11                   5            0.84
# 3   Perşembe                  13                   3            0.78
# 4       Cuma                  14                   4            0.72
# 5  Cumartesi                  14                   5            0.73
# 6      Pazar                  16                   5            0.65
#
#   Rüzgar Hızı  Beklenen Hadise
# 0      7 km/h         YAĞMURLU
# 1     17 km/h  SAĞANAK YAĞIŞLI
# 2      8 km/h         YAĞMURLU
# 3      7 km/h         YAĞMURLU
# 4     14 km/h         YAĞMURLU
# 5     16 km/h  SAĞANAK YAĞIŞLI
# 6     13 km/h  SAĞANAK YAĞIŞLI

# %% [markdown]
# **ESKİŞEHİR**

# %%
df_eskişehir= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Eskişehir")
df_eskişehir
# Out:
#    ESKİŞEHİR  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  17                   7            0.52  \
# 1       Salı                  16                   6            0.33
# 2   Çarşamba                  18                   5            0.14
# 3   Perşembe                  15                   5            0.24
# 4       Cuma                  19                   5            0.71
# 5  Cumartesi                  19                   7            0.40
# 6      Pazar                  21                   8            0.24
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     22 km/h         YAĞMURLU
# 1     18 km/h         YAĞMURLU
# 2     15 km/h  PARÇALI BULUTLU
# 3     17 km/h  PARÇALI BULUTLU
# 4     13 km/h         YAĞMURLU
# 5     12 km/h         YAĞMURLU
# 6     14 km/h  PARÇALI BULUTLU

# %% [markdown]
# **GAZİANTEP**

# %%
df_gaziantep= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Gaziantep")
df_gaziantep
# Out:
#    GAZİANTEP  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  26                  14            0.10  \
# 1       Salı                  23                   9            0.61
# 2   Çarşamba                  21                   9            0.19
# 3   Perşembe                  21                  10            0.78
# 4       Cuma                  23                   9            0.15
# 5  Cumartesi                  24                  11            0.10
# 6      Pazar                  25                  12            0.24
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     19 km/h  PARÇALI BULUTLU
# 1     22 km/h    SAĞANAK YAĞIŞ
# 2     21 km/h  PARÇALI BULUTLU
# 3     12 km/h  SAĞANAK YAĞIŞLI
# 4     16 km/h  PARÇALI BULUTLU
# 5     14 km/h  PARÇALI BULUTLU
# 6     14 km/h  PARÇALI BULUTLU

# %% [markdown]
# **HATAY**

# %%
df_hatay= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Hatay")
df_hatay
# Out:
#        HATAY  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  24                  14            0.15  \
# 1       Salı                  23                  14            0.73
# 2   Çarşamba                  24                  14            0.74
# 3   Perşembe                  25                  14            0.24
# 4       Cuma                  28                  15            0.24
# 5  Cumartesi                  29                  15            0.12
# 6      Pazar                  27                  15            0.15
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     30 km/h          GÜNEŞLİ
# 1     28 km/h         YAĞMURLU
# 2     26 km/h  SAĞANAK YAĞIŞLI
# 3     24 km/h  PARÇALI BULUTLU
# 4     20 km/h  PARÇALI BULUTLU
# 5     19 km/h  PARÇALI BULUTLU
# 6     25 km/h          GÜNEŞLİ

# %% [markdown]
# **İSTANBUL**

# %%
df_istanbul= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="İstanbul")
df_istanbul
# Out:
#     İSTANBUL  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  15                  11            0.81  \
# 1       Salı                  16                  12            0.74
# 2   Çarşamba                  16                  10            0.52
# 3   Perşembe                  17                  10            0.10
# 4       Cuma                  16                  10            0.08
# 5  Cumartesi                  16                  10            0.07
# 6      Pazar                  16                  10            0.08
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     31 km/h         YAĞMURLU
# 1     30 km/h         YAĞMURLU
# 2     28 km/h  PARÇALI BULUTLU
# 3     33 km/h          BULUTLU
# 4     30 km/h  PARÇALI BULUTLU
# 5     27 km/h  PARÇALI BULUTLU
# 6     22 km/h  PARÇALI BULUTLU

# %% [markdown]
# **İZMİR**

# %%
df_izmir= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="İzmir")
df_izmir
# Out:
#        İZMİR  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  23                  13            0.19  \
# 1       Salı                  23                  11            0.82
# 2   Çarşamba                  17                   8            0.61
# 3   Perşembe                  19                   6            0.10
# 4       Cuma                  18                   7            0.08
# 5  Cumartesi                  18                   7            0.21
# 6      Pazar                  20                   8            0.24
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     11 km/h          BULUTLU
# 1     11 km/h         YAĞMURLU
# 2     11 km/h         YAĞMURLU
# 3      7 km/h  PARÇALI BULUTLU
# 4      8 km/h          GÜNEŞLİ
# 5      6 km/h  PARÇALI BULUTLU
# 6      6 km/h  PARÇALI BULUTLU

# %% [markdown]
# **KONYA**

# %%
df_konya= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Konya")
df_konya
# Out:
#        KONYA  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  20                   8            0.82  \
# 1       Salı                  17                   9            0.81
# 2   Çarşamba                  19                   7            0.15
# 3   Perşembe                  20                   8            0.36
# 4       Cuma                  19                   8            0.52
# 5  Cumartesi                  21                   8            0.36
# 6      Pazar                  21                  10            0.33
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     21 km/h  SAĞANAK YAĞIŞLI
# 1     17 km/h  SAĞANAK YAĞIŞLI
# 2     18 km/h  PARÇALI BULUTLU
# 3     16 km/h         YAĞMURLU
# 4     15 km/h         YAĞMURLU
# 5     14 km/h         YAĞMURLU
# 6     16 km/h         YAĞMURLU

# %% [markdown]
# **KAYSERİ**

# %%
df_kayseri= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Kayseri")
df_kayseri
# Out:
#      KAYSERİ  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  22                   8            0.54  \
# 1       Salı                  17                   7            0.87
# 2   Çarşamba                  17                   6            0.57
# 3   Perşembe                  18                   6            0.22
# 4       Cuma                  19                   6            0.72
# 5  Cumartesi                  19                   7            0.50
# 6      Pazar                  20                   8            0.59
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     23 km/h  SAĞANAK YAĞIŞLI
# 1     12 km/h         YAĞMURLU
# 2     14 km/h         YAĞMURLU
# 3     12 km/h  PARÇALI BULUTLU
# 4     13 km/h         YAĞMURLU
# 5     11 km/h         YAĞMURLU
# 6     15 km/h         YAĞMURLU

# %% [markdown]
# **KOCAELİ**

# %%
df_kocaeli= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Kocaeli")
df_kocaeli
# Out:
#      KOCAELİ  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  18                  10            0.77  \
# 1       Salı                  20                   9            0.68
# 2   Çarşamba                  21                   9            0.24
# 3   Perşembe                  17                   8            0.24
# 4       Cuma                  17                   7            0.64
# 5  Cumartesi                  19                   8            0.42
# 6      Pazar                  20                   9            0.38
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     18 km/h         YAĞMURLU
# 1     15 km/h         YAĞMURLU
# 2     17 km/h  PARÇALI BULUTLU
# 3     20 km/h          BULUTLU
# 4     18 km/h         YAĞMURLU
# 5     17 km/h         YAĞMURLU
# 6     14 km/h         YAĞMURLU

# %% [markdown]
# **MERSİN**

# %%
df_mersin= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Mersin")
df_mersin
# Out:
#       MERSİN  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  16                   6            0.64  \
# 1       Salı                  15                   4            0.77
# 2   Çarşamba                  11                   5            0.84
# 3   Perşembe                  13                   3            0.78
# 4       Cuma                  14                   4            0.72
# 5  Cumartesi                  14                   5            0.73
# 6      Pazar                  16                   6            0.65
#
#   Rüzgar Hızı  Beklenen Hadise
# 0      7 km/h         YAĞMURLU
# 1     17 km/h  SAĞANAK YAĞIŞLI
# 2      8 km/h         YAĞMURLU
# 3      7 km/h         YAĞMURLU
# 4     14 km/h         YAĞMURLU
# 5     16 km/h  SAĞANAK YAĞIŞLI
# 6     13 km/h  SAĞANAK YAĞIŞLI

# %% [markdown]
# **SAKARYA**

# %%
df_sakarya= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Sakarya")
df_sakarya
# Out:
#      SAKARYA  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  17                  10            0.79  \
# 1       Salı                  18                   9            0.74
# 2   Çarşamba                  19                   8            0.24
# 3   Perşembe                  17                   8            0.24
# 4       Cuma                  16                   7            0.68
# 5  Cumartesi                  19                   8            0.40
# 6      Pazar                  19                   9            0.38
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     15 km/h         YAĞMURLU
# 1     14 km/h         YAĞMURLU
# 2     16 km/h  PARÇALI BULUTLU
# 3     18 km/h          BULUTLU
# 4     16 km/h         YAĞMURLU
# 5     14 km/h         YAĞMURLU
# 6     13 km/h         YAĞMURLU

# %% [markdown]
# **SAMSUN**

# %%
df_samsun= pd.read_excel("/Users/kubilaycantuna/Desktop/YetGen_Proje.xlsx", sheet_name="Samsun")
df_samsun
# Out:
#       SAMSUN  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  16                  11            0.90  \
# 1       Salı                  16                  12            0.79
# 2   Çarşamba                  15                  10            0.75
# 3   Perşembe                  12                   9            0.49
# 4       Cuma                  13                  10            0.76
# 5  Cumartesi                  14                  10            0.72
# 6      Pazar                  16                  11            0.66
#
#   Rüzgar Hızı  Beklenen Hadise
# 0      8 km/h  SAĞANAK YAĞIŞLI
# 1     14 km/h         YAĞMURLU
# 2     13 km/h         YAĞMURLU
# 3     11 km/h         YAĞMURLU
# 4      9 km/h         YAĞMURLU
# 5      7 km/h         YAĞMURLU
# 6      7 km/h         YAĞMURLU

# %% [markdown]
# **ANA KOD:**

# %%
şehirler= ["Adana","Ankara","Antalya","Aydın","Balıkesir","Bursa","Denizli",
           "Diyarbakır","Erzurum","Eskişehir","Gaziantep","Hatay","Istanbul",
           "Izmir","Konya","Kayseri","Kocaeli","Mersin","Sakarya","Samsun" ]

def display_şehirler():
    print("Aşağıdaki tüm şehirlerin haftalık hava durumunu öğrenebilirsiniz.\n")
    print("-------- MEVCUT ŞEHİRLER --------")
    for sehir in şehirler:
       print(sehir)
    print("\n")

def hava_durumu():
    display_şehirler()
    tercih= input("Hangi şehrin hava durumunu öğrenmek istersin?")
    tercih_düzeltilmiş= tercih.lower().capitalize()
   
    
    assert tercih_düzeltilmiş in şehirler, "Bu şehrimizin hava durumu bilgileri şuanda mevcut değil. Başka bir şehir için bilgi almak isterseniz programı tekrar başlatın."

    if tercih_düzeltilmiş == "Adana":
        print("Adana'nın haftalık Hava Durumu:\n")
        print(df_adana)
    
    elif tercih_düzeltilmiş == "Ankara":
        print("Ankara'nın haftalık Hava Durumu:\n")
        print(df_ankara)
    
    elif tercih_düzeltilmiş == "Antalya":
        print("Antalya'nın haftalık Hava Durumu:\n")
        print(df_antalya)
    
    elif tercih_düzeltilmiş == "Aydın":
        print("Aydın'ın haftalık Hava Durumu:\n")
        print(df_aydın)
    
    elif tercih_düzeltilmiş == "Balıkesir":
        print("Balıkesir'in haftalık Hava Durumu:\n")
        print(df_balıkesir)
    
    elif tercih_düzeltilmiş == "Bursa":
        print("Bursa'nın haftalık Hava Durumu:\n")
        print(df_bursa)
    
    elif tercih_düzeltilmiş == "Denizli":
        print("Denizli'nin haftalık Hava Durumu:\n")
        print(df_denizli)
    
    elif tercih_düzeltilmiş == "Diyarbakır":
        print("Diyarbakır'ın haftalık Hava Durumu:\n")
        print(df_diyarbakır)
    
    elif tercih_düzeltilmiş == "Erzurum":
        print("Erzurum'un haftalık Hava Durumu:\n")
        print(df_erzurum)
    
    elif tercih_düzeltilmiş == "Eskişehir":
        print("Eskişehir'in haftalık Hava Durumu:\n")
        print(df_eskişehir)
    
    elif tercih_düzeltilmiş == "Gaziantep":
        print("Gaziantep'in haftalık Hava Durumu:\n")
        print(df_gaziantep)
    
    elif tercih_düzeltilmiş == "Hatay":
        print("Hatay'ın haftalık Hava Durumu:\n")
        print(df_hatay)
    
    elif tercih_düzeltilmiş == "Istanbul":
        print("İstanbul'un haftalık Hava Durumu:\n")
        print(df_istanbul)
    
    elif tercih_düzeltilmiş == "Izmir":
        print("İzmir'in haftalık Hava Durumu:\n")
        print(df_izmir)
    
    elif tercih_düzeltilmiş == "Kayseri":
        print("Kayseri'nın haftalık Hava Durumu:\n")
        pint(df_kayseri)
    
    elif tercih_düzeltilmiş == "Kocaeli":
        print("Kocaeli'nin haftalık Hava Durumu:\n")
        print(df_kocaeli)
    
    elif tercih_düzeltilmiş == "Konya":
        print("Konya'nın haftalık Hava Durumu:\n")
        print(df_konya)
    
    elif tercih_düzeltilmiş == "Mersin":
        print("Mersin'in haftalık Hava Durumu:\n")
        print(df_mersin)
    
    elif tercih_düzeltilmiş == "Sakarya":
        print("Sakarya'nın haftalık Hava Durumu:\n")
        print(df_sakarya)
    
    elif tercih_düzeltilmiş == "Samsun":
        print("Samsun'un haftalık Hava Durumu:\n")
        print(df_samsun)
                



def main():
    print("AlpaPy Hava Durumu Sorgulayıcıya Hoşgeldiniz.\n")
    print("Hava durumu sorgulayabileceğiniz şehirleri görmek için 1'e basınız. Hava durumu sorgulamak  için 2'ye, çıkmak için ise 0'a basınız.\n")

    program= None

    while True:
        program=int(input("Yapmak istediğiniz işlemi tuşla sana hemen yardımcı oliyım."))

        if program < 0 or program > 2:
            print("Yanlış bir rakamı tuşladın. Kontrol edebilir misin?")
        elif program == 0:
            print("Umarım yardımcı olabilmişimdir. İyi günler dlerim.")
            break
        elif program == 1:
            display_şehirler()
        elif program == 2:
            hava_durumu()
        
            kontrol=input("Başka bir şehrin hava durumunu öğrenmek ister misin?")

            if kontrol.lower()=="evet":
                pass 
            else:
              print("Umarım yardımcı olabilmişimdir. İyi günler dlerim.")
              break

# %%
main()
# Out:
# AlpaPy Hava Durumu Sorgulayıcıya Hoşgeldiniz.
#
# Hava durumu sorgulayabileceğiniz şehirleri görmek için 1'e basınız. Hava durumu sorgulamak  için 2'ye, çıkmak için ise 0'a basınız.
#
# Aşağıdaki tüm şehirlerin haftalık hava durumunu öğrenebilirsiniz.
#
# -------- MEVCUT ŞEHİRLER --------
# Adana
# Ankara
# Antalya
# Aydın
# Balıkesir
# Bursa
# Denizli
# Diyarbakır
# Erzurum
# Eskişehir
# Gaziantep
# Hatay
# Istanbul
# Izmir
# Konya
# Kayseri
# Kocaeli
# Mersin
# Sakarya
# Samsun
#
#
# Gaziantep'in haftalık Hava Durumu:
#
#    GAZİANTEP  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  26                  14            0.10  \
# 1       Salı                  23                   9            0.61
# 2   Çarşamba                  21                   9            0.19
# 3   Perşembe                  21                  10            0.78
# 4       Cuma                  23                   9            0.15
# 5  Cumartesi                  24                  11            0.10
# 6      Pazar                  25                  12            0.24
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     19 km/h  PARÇALI BULUTLU
# 1     22 km/h    SAĞANAK YAĞIŞ
# 2     21 km/h  PARÇALI BULUTLU
# 3     12 km/h  SAĞANAK YAĞIŞLI
# 4     16 km/h  PARÇALI BULUTLU
# 5     14 km/h  PARÇALI BULUTLU
# 6     14 km/h  PARÇALI BULUTLU
# Umarım yardımcı olabilmişimdir. İyi günler dlerim.

# %%
# Tüm kodlar takır takır çalışıyor. Sadece output boyutu büyük olduğu için text editörden ya da scrollable element'den bakmak gerekebilir.
