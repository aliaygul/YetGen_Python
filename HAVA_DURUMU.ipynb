# %%
import numpy as np
import pandas as pd
import time

# %%
# Excel dosyasını açabilmek için indirilmesi gerek
pip install openpyxl

# %%
# Ne olur ne  olmaz yedeği (elleşmek yasak)

print("HAVA DURUMUNA HOŞ GELDİNİZ")

while True:
    a=input("Şehir Menüsüne Erişmek İçin '1'e, Detaylı Şehir Görünümü İçin 2'ye Basınız")
    if a == "1":
        a=["İstanbul","Ankara","İzmir","Adana","Bursa","Gaziantep","Konya","Kayseri","Antalya","Diyarbakır","Eskişehir","Erzurum","Mersin","Kocaeli","Samsun","Sakarya","Aydın","Balıkasir","Denizli","Hatay"]
        column1 = a[:len(a)//2]
        column2 = a[len(a)//2:]
        for city1, city2 in zip(column1, column2):
            print(f"{city1:<15}{city2}")
    elif a=="2":
        print("İstanbul'a erişmek için 'a'\nAnkara'ya erişmek için 'b'\nİzmir'e erişmek için 'c'\nAdana'ya erişmek için 'd'\nBursa'ya erişmek için 'e'\nGaziantep'e erişmek için 'f'\nKonya'ya erişmek için 'g'\nKayseri'ye erişmek için 'h'\nAntalya'ya erişmek için 'i'\nDiyarbakır'a erişmek için 'j'\nEskişehir'e erişmek için 'k'\nErzurum'a erişmek için 'l'\nMersin'e erişmek için 'm'\nKocaeli'ne erişmek için 'n'\nSamsun'a erişmek için 'o'\nSakarya'ya erişmek için 'p'\nAydın'a erişmek için 'q'\nBalıkesir'e erişmek için 'r'\nDenizli'ye erişmek için 's'\nHatay'a erişmek için 't'\nÇıkış yapmak için 'u' ")
        işlem=input("Yapmak istediğiniz işlemi giriniz:")

        if işlem == "q":
            print("Çıkış yapılıyor")
            break
        
        elif işlem == "a":
        
        elif işlem == "b":
        
        elif işlem == "c":
        
        elif işlem == "d":
        
        elif işlem == "e":
        
        elif işlem == "f":

        elif işlem == "g":

        elif işlem == "h":

        elif işlem == "i":
        
        elif işlem == "j":
        
        elif işlem == "k":
        
        elif işlem == "l":
        
        elif işlem == "m":
        
        elif işlem == "n":

        elif işlem == "o":

        elif işlem == "p":
        
        elif işlem == "q":

        elif işlem == "r":

        elif işlem == "s":

        elif işlem == "t":

        elif işlem == "u":

# %%
# Deney tahtası
# Sürekli bir loop halinde '2'ye basınca ve printlemiyor
print("HAVA DURUMUNA HOŞ GELDİNİZ")

while True:
    a=input("Şehir Menüsüne Erişmek İçin '1'e, Detaylı Şehir Görünümü İçin 2'ye Basınız")
    if a == "1":
        b=["İstanbul","Ankara","İzmir","Adana","Bursa","Gaziantep","Konya","Kayseri","Antalya","Diyarbakır","Eskişehir","Erzurum","Mersin","Kocaeli","Samsun","Sakarya","Aydın","Balıkasir","Denizli","Hatay"]
        column1 = b[:len(b)//2]
        column2 = b[len(b)//2:]
        for city1, city2 in zip(column1, column2):
            print(f"{city1:<15}{city2}")
    
    elif a=="2":
        print("İstanbul'a erişmek için 'a'\nAnkara'ya erişmek için 'b'\nİzmir'e erişmek için 'c'\nAdana'ya erişmek için 'd'\nBursa'ya erişmek için 'e'\nGaziantep'e erişmek için 'f'\nKonya'ya erişmek için 'g'\nKayseri'ye erişmek için 'h'\nAntalya'ya erişmek için 'i'\nDiyarbakır'a erişmek için 'j'\nEskişehir'e erişmek için 'k'\nErzurum'a erişmek için 'l'\nMersin'e erişmek için 'm'\nKocaeli'ne erişmek için 'n'\nSamsun'a erişmek için 'o'\nSakarya'ya erişmek için 'p'\nAydın'a erişmek için 'q'\nBalıkesir'e erişmek için 'r'\nDenizli'ye erişmek için 's'\nHatay'a erişmek için 't'\nÇıkış yapmak için 'u' ")
        işlem=input("Yapmak istediğiniz işlemi giriniz:")

        if işlem == "u":
            print("Çıkış yapılıyor")
            break
        elif işlem == "a":
            df_istanbul= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="İstanbul")
            print(df_istanbul)  
            
        elif işlem == "b":
            df_ankara= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Ankara")
            print(df_ankara)
            
        elif işlem == "c":
            df_izmir= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="İzmir")
            print(df_izmir)

        elif işlem == "d":
            df_adana= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Adana")
            print(df_adana)
            
        elif işlem == "e":
            df_bursa= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Bursa")
            print(df_bursa)

        elif işlem == "f":
            df_gaziantep= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Gaziantep")
            print(df_gaziantep)
            
        elif işlem == "g":
            df_konya= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Konya")
            print(df_konya)

        elif işlem == "h":
            df_kayseri= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Kayseri")
            print(df_kayseri)
            
        elif işlem == "i":
            df_antalya= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Antalya")
            print(df_antalya)
            
        elif işlem == "j":
            df_diyarbakır= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Diyarbakır")
            print(df_diyarbakır)
            
        elif işlem == "k":
            df_eskişehir= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Eskişehir")
            print(df_eskişehir)
            
        elif işlem == "l":
            df_erzurum= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Erzurum")
            print(df_erzurum)
            
        elif işlem == "m":
            df_mersin= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Mersin")
            print(df_mersin)
            
        elif işlem == "n":
            df_kocaeli= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Kocaeli")
            print(df_kocaeli)
            
        elif işlem == "o":
            df_samsun= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Samsun")
            print(df_samsun)
            
        elif işlem == "p":
            df_sakarya= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Sakarya")
            print(df_sakarya)
            
        elif işlem == "q":
            df_aydın= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Aydın")
            print(df_aydın)
            
        elif işlem == "r":
            df_balıkesir= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Balıkesir")
            print(df_balıkesir)
            
        elif işlem == "s":
            df_denizli= pd.read_excel("C:/Users\ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Denizli")
            print(df_denizli)
            
        elif işlem == "t":
            df_hatay= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Hatay")
            print(df_hatay)

# %%
import numpy as np
import pandas as pd
import time


print("HAVA DURUMUNA HOŞ GELDİNİZ")
print("Program başlatılıyor...")

while True:
    a=input("Şehir Menüsüne Erişmek İçin '1'e, Detaylı Şehir Görünümü İçin 2'ye Basınız")
    if a == "1":
        b=["İstanbul","Ankara","İzmir","Adana","Bursa","Gaziantep","Konya","Kayseri","Antalya","Diyarbakır","Eskişehir","Erzurum","Mersin","Kocaeli","Samsun","Sakarya","Aydın","Balıkasir","Denizli","Hatay"]
        # Aşağıda yer alan kod sayesinde b değişkenindeki vdrilerimiz 2 sütun halinde eşit aralıklarla alt alta bastırılacaktır.
        column1 = b[:len(b)//2]
        column2 = b[len(b)//2:]
        for city1, city2 in zip(column1, column2):
            print(f"{city1:<15}{city2}")
            
    elif a=="2":
        print("İstanbul'a erişmek için 'a'\nAnkara'ya erişmek için 'b'\nİzmir'e erişmek için 'c'\nAdana'ya erişmek için 'd'\nBursa'ya erişmek için 'e'\nGaziantep'e erişmek için 'f'\nKonya'ya erişmek için 'g'\nKayseri'ye erişmek için 'h'\nAntalya'ya erişmek için 'i'\nDiyarbakır'a erişmek için 'j'\nEskişehir'e erişmek için 'k'\nErzurum'a erişmek için 'l'\nMersin'e erişmek için 'm'\nKocaeli'ne erişmek için 'n'\nSamsun'a erişmek için 'o'\nSakarya'ya erişmek için 'p'\nAydın'a erişmek için 'q'\nBalıkesir'e erişmek için 'r'\nDenizli'ye erişmek için 's'\nHatay'a erişmek için 't'\nÇıkış yapmak için 'u' ")
        işlem=input("Yapmak istediğiniz işlemi giriniz:")

        if işlem == "u":
            print("Çıkış yapılıyor")
            break
        elif işlem == "a":
            df_istanbul= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="İstanbul")
            print(df_istanbul)  
            
        elif işlem == "b":
            df_ankara= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Ankara")
            print(df_ankara)
            
        elif işlem == "c":
            df_izmir= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="İzmir")
            print(df_izmir)

        elif işlem == "d":
            df_adana= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Adana")
            print(df_adana)
            
        elif işlem == "e":
            df_bursa= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Bursa")
            print(df_bursa)

        elif işlem == "f":
            df_gaziantep= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Gaziantep")
            print(df_gaziantep)
            
        elif işlem == "g":
            df_konya= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Konya")
            print(df_konya)

        elif işlem == "h":
            df_kayseri= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Kayseri")
            print(df_kayseri)
            
        elif işlem == "i":
            df_antalya= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Antalya")
            print(df_antalya)
            
        elif işlem == "j":
            df_diyarbakır= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Diyarbakır")
            print(df_diyarbakır)
            
        elif işlem == "k":
            df_eskişehir= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Eskişehir")
            print(df_eskişehir)
            
        elif işlem == "l":
            df_erzurum= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Erzurum")
            print(df_erzurum)
            
        elif işlem == "m":
            df_mersin= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Mersin")
            print(df_mersin)
            
        elif işlem == "n":
            df_kocaeli= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Kocaeli")
            print(df_kocaeli)
            
        elif işlem == "o":
            df_samsun= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Samsun")
            print(df_samsun)
            
        elif işlem == "p":
            df_sakarya= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Sakarya")
            print(df_sakarya)
            
        elif işlem == "q":
            df_aydın= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Aydın")
            print(df_aydın)
            
        elif işlem == "r":
            df_balıkesir= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Balıkesir")
            print(df_balıkesir)
            
        elif işlem == "s":
            df_denizli= pd.read_excel("C:/Users\ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Denizli")
            print(df_denizli)
            
        elif işlem == "t":
            df_hatay= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="Hatay")
            print(df_hatay)
# Out:
# HAVA DURUMUNA HOŞ GELDİNİZ
# Program başlatılıyor...
# İstanbul       Eskişehir
# Ankara         Erzurum
# İzmir          Mersin
# Adana          Kocaeli
# Bursa          Samsun
# Gaziantep      Sakarya
# Konya          Aydın
# Kayseri        Balıkasir
# Antalya        Denizli
# Diyarbakır     Hatay
# İstanbul'a erişmek için 'a'
# Ankara'ya erişmek için 'b'
# İzmir'e erişmek için 'c'
# Adana'ya erişmek için 'd'
# Bursa'ya erişmek için 'e'
# Gaziantep'e erişmek için 'f'
# Konya'ya erişmek için 'g'
# Kayseri'ye erişmek için 'h'
# Antalya'ya erişmek için 'i'
# Diyarbakır'a erişmek için 'j'
# Eskişehir'e erişmek için 'k'
# Erzurum'a erişmek için 'l'
# Mersin'e erişmek için 'm'
# Kocaeli'ne erişmek için 'n'
# Samsun'a erişmek için 'o'
# Sakarya'ya erişmek için 'p'
# Aydın'a erişmek için 'q'
# Balıkesir'e erişmek için 'r'
# Denizli'ye erişmek için 's'
# Hatay'a erişmek için 't'
# Çıkış yapmak için 'u'
# Çıkış yapılıyor

# %%
df_izmir= pd.read_excel("C:/Users/ali-a/OneDrive/Masaüstü/YetGeN_Proje.xlsx", sheet_name="İzmir")
df_izmir
# Out:
#        İZMİR  Sabah Sıcaklıkları  Akşam Sıcaklıkları  Yağış İhtimali
# 0  Pazartesi                  23                  13            0.19  \
# 1       Salı                  23                  11            0.82
# 2   Çarşamba                  17                   8            0.61
# 3   Perşembe                  19                   6            0.10
# 4       Cuma                  18                   7            0.08
# 5  Cumartesi                  18                   7            0.21
# 6      Pazar                  20                   8            0.24
#
#   Rüzgar Hızı  Beklenen Hadise
# 0     11 km/h          BULUTLU
# 1     11 km/h         YAĞMURLU
# 2     11 km/h         YAĞMURLU
# 3      7 km/h  PARÇALI BULUTLU
# 4      8 km/h          GÜNEŞLİ
# 5      6 km/h  PARÇALI BULUTLU
# 6      6 km/h  PARÇALI BULUTLU
