# %% [markdown]
# # Problem 1
# Kullanıcıdan bir sayı alınız. Sayı 0'dan büyükse pozitif , 0'dan küçükse negatif sıfıra eşitse sıfır yazdırınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
sayi1=int(input("Bir sayı giriniz:"))

if sayi1>0:
    print(f"{sayi1} pozitif sayıdır.")
elif sayi1<0:
    print(f"{sayi1} negatif sayıdır.")
else:
    print(f"{sayi1} nötrdür.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 # 1.Problemin Çözümünü Buraya Yazınız
# ----> 2 sayi1=int(input("Bir sayı giriniz:"))
#       4 if sayi1>0:
#       5     print(f"{sayi1} pozitif sayıdır.")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
#  # Problem 2
# Kullanıcıdan aldığınız bir sayının mükemmel olup olmadığını bulmaya çalışın.
# Bir sayının kendi hariç bölenlerinin toplamı kendine eşitse bu sayıya "mükemmel sayı" denir. Örnek olarak, 6 mükemmel bir sayıdır. (1 + 2 + 3 = 6)

# %%
# Sayı adına bir değişken oluşturup kullanıcıdan bir sayı alınır

sayi=int(input("Bir sayı giriniz:"))

# Toplam adına bir değişken oluşturup 0'a atayalım

toplam=0

# Girilen sayı ile bir arasında gezelim, bunu range() fonksiyonu ile yaparız. range(başlangı, bitiş, artış miktarı)

for i in range(1,sayi):

    # Eğer sayı i değişkenine tam bölünüyorsa toplama i değerini ekleyelim

    if(sayi%i==0): # Buradaki i değeri range fonksiyonun içindeki sayılari yani i ilk birden başlayıp sayi'ya kadar tanımlanacak.

        toplam +=i

# Sayı değeri toplam değerine eşitse "Mükemmel Sayı", eşit değilse "Mükemmel Sayı Değildir" yazdıralım

if(sayi==toplam):

    print("Mükemmel Sayıdır")

else:

    print("Mükemmel Sayı Değildir")
# Out:
# Mükemmel Sayı Değildir

# %% [markdown]
#  # Problem 3
# Kullanıcıdan aldığınız bir sayının "Armstrong" sayısı olup olmadığını bulmaya çalışın.
# Örnek olarak, Bir sayı eğer 4 basamaklı ise ve oluşturan rakamlardan herbirinin 4. kuvvetinin toplamı( 3 basamaklı sayılar için 3.kuvveti ) o sayıya eşitse bu sayıya "Armstrong" sayısı denir.
#
# Örnek olarak : 1634 = 1^4 + 6^4 + 3^4 + 4^4

# %%
# 3.Problemin Çözümünü Buraya Yazınız
sayicik= int(input("Bir sayı giriniz:"))

# basamak adına değişken oluşturup sayi değerini string'e çevirelim
basamak=str(sayicik)
toplam = 0

# for döngüsü ile basamak değerlerini gezelim ve rakam adında değişken oluşturup basamağın karakter sayısı ile basamak değerlerini çarpalım
# toplam değerine rakamı ekleyelim
for x in basamak:
    rakam = int(x) ** len(basamak) # len fonksiyonu string değerinin basamak sayısını verir
    toplam += rakam

if toplam ==sayicik:
    print(f"{sayicik} Armstrong Sayı")
else:
    print(f"{sayicik} Armstrong Sayısı Değil")
# Out:
# 1234 Armstrong Sayısı Değil

# %% [markdown]
# # Problem 4
# YetGen Core Python mezunu bir öğretmenimiz öğrencilerine 1'den 10'a kadar sayılarla çarpım tablosunu öğretirken Python'dan destek almak istiyor. Bu konuda öğretmenimize yardımcı olmak ister misin?
#
# İpucu: İç içe 2 tane for döngüsü kullanın.
#
# Aynı zamanda sayıları range() fonksiyonunu kullanarak elde edin.

# %%
# 4.Problemin Çözümünü Buraya Yazınız
print("ÇARPIM TAPLOSUNA HOŞGELDİNİZ")
for j in range(1,11):
    for i in range(0,11):
        print(f"{j} * {i} = {j*i}", end="\t") #
    print()
# Out:
# ÇARPIM TAPLOSUNA HOŞGELDİNİZ
# 1 * 0 = 0	1 * 1 = 1	1 * 2 = 2	1 * 3 = 3	1 * 4 = 4	1 * 5 = 5	1 * 6 = 6	1 * 7 = 7	1 * 8 = 8	1 * 9 = 9	1 * 10 = 10
# 2 * 0 = 0	2 * 1 = 2	2 * 2 = 4	2 * 3 = 6	2 * 4 = 8	2 * 5 = 10	2 * 6 = 12	2 * 7 = 14	2 * 8 = 16	2 * 9 = 18	2 * 10 = 20
# 3 * 0 = 0	3 * 1 = 3	3 * 2 = 6	3 * 3 = 9	3 * 4 = 12	3 * 5 = 15	3 * 6 = 18	3 * 7 = 21	3 * 8 = 24	3 * 9 = 27	3 * 10 = 30
# 4 * 0 = 0	4 * 1 = 4	4 * 2 = 8	4 * 3 = 12	4 * 4 = 16	4 * 5 = 20	4 * 6 = 24	4 * 7 = 28	4 * 8 = 32	4 * 9 = 36	4 * 10 = 40
# 5 * 0 = 0	5 * 1 = 5	5 * 2 = 10	5 * 3 = 15	5 * 4 = 20	5 * 5 = 25	5 * 6 = 30	5 * 7 = 35	5 * 8 = 40	5 * 9 = 45	5 * 10 = 50
# 6 * 0 = 0	6 * 1 = 6	6 * 2 = 12	6 * 3 = 18	6 * 4 = 24	6 * 5 = 30	6 * 6 = 36	6 * 7 = 42	6 * 8 = 48	6 * 9 = 54	6 * 10 = 60
# 7 * 0 = 0	7 * 1 = 7	7 * 2 = 14	7 * 3 = 21	7 * 4 = 28	7 * 5 = 35	7 * 6 = 42	7 * 7 = 49	7 * 8 = 56	7 * 9 = 63	7 * 10 = 70
# 8 * 0 = 0	8 * 1 = 8	8 * 2 = 16	8 * 3 = 24	8 * 4 = 32	8 * 5 = 40	8 * 6 = 48	8 * 7 = 56	8 * 8 = 64	8 * 9 = 72	8 * 10 = 80
# 9 * 0 = 0	9 * 1 = 9	9 * 2 = 18	9 * 3 = 27	9 * 4 = 36	9 * 5 = 45	9 * 6 = 54	9 * 7 = 63	9 * 8 = 72	9 * 9 = 81	9 * 10 = 90
# 10 * 0 = 0	10 * 1 = 10	10 * 2 = 20	10 * 3 = 30	10 * 4 = 40	10 * 5 = 50	10 * 6 = 60	10 * 7 = 70	10 * 8 = 80	10 * 9 = 90	10 * 10 = 100

# %% [markdown]
# # Problem 5
# Markete giren bir YetGen'li sıra beklememek için hızlı kasaya gider. Hızlı kasanın çalışma mantığı şu şekildedir:
# - Kullanıcının aldığı her ürünün fiyatını tek tek girmesi gerekir.
# - Kullanıcı kasadan çıkmak isterse q tuşuna basmalıdır.
# - Kasa girilen fiyatları son fiyat isimli değişkene ekler.
# - Değişkeni ekrana bastırır.
#
# İpucu: while döngüsünü sonsuz koşulla başlatın ve kullanıcı q'ya basarsa döngüyü break ile sonlandırın.

# %%
# 5.Problemin Çözümünü Buraya Yazınız
toplams=0

# while döngüsü True olduğu sürece gezmeyi sağlayalım.
while True:
    secim=input("Çıkmak için 'q', diğer durumlarda sayı giriniz: ")

    if secim =="q":
        print("Uygulama Sonlandırıldı")
        break
    else:
        sayi = int(secim)
        toplams+= sayi

print(f"{toplam} TL tutarında tuttu.")
# Out:
# Uygulama Sonlandırıldı
# 354 TL tutarında tuttu.

# %% [markdown]
# # Problem 6
# 1'den 100'e kadar olan sayılardan sadece 3'e bölünen sayıları ekrana bastırın. Bu işlemi continue ile yapmaya çalışın.

# %%
# 6.Problemin Çözümünü Buraya Yazınız
for i in range(1,101):
    if i % 3 == 0 :
        print(i, end="\t")
    else: # for fonksiyonunun devam etmesini sağlıyor, eğer sayı 3'e bölünmüyorsa devam ettiriyor.
        continue
# Out:
# 3	6	9	12	15	18	21	24	27	30	33	36	39	42	45	48	51	54	57	60	63	66	69	72	75	78	81	84	87	90	93	96	99

# %% [markdown]
# # Problem 7
# Bir YetGen Core Python mezunu MEF Üniversitesi'nde Bilgisayar Bilimleri Doktora programının mülakatına girmeye hak kazanıyor. Mülakata hazırlanırken internetten soru araştırıyor. Karşısına çıkan ünlü FizzBuzz sorusuna benzer YetGen sorusunda kendisini yeterince hazır hissetmiyor. Bu soruyu çözmesine destek olmak ister misin?
#
# Soru aşağıdaki gibidir:
#
# 1’den 100’e kadar sayıları yazdırıyoruz. Ancak eğer sayı 3’e bölünüyor ise Yet, sayı 5’e bölünüyorsa Gen, hem 3’e hem 5’e bölünüyorsa YetGen yazdırıyoruz.

# %%
# 7.Problemin Çözümünü Buraya Yazınız

for i in range(1,101):
    
    if i % 3 == 0:
        print("YET")
        
    elif i % 5 ==0 and i % 3 == 0:
        print("YETGEN")

    elif i % 5 ==0:
        print("GEN")
    
    else:
        print(i)
# Out:
# 1
# 2
# YET
# 4
# GEN
# YET
# 7
# 8
# YET
# GEN
# 11
# YET
# 13
# 14
# YET
# 16
# 17
# YET
# 19
# GEN
# YET
# 22
# 23
# YET
# GEN
# 26
# YET
# 28
# 29
# YET
# 31
# 32
# YET
# 34
# GEN
# YET
# 37
# 38
# YET
# GEN
# 41
# YET
# 43
# 44
# YET
# 46
# 47
# YET
# 49
# GEN
# YET
# 52
# 53
# YET
# GEN
# 56
# YET
# 58
# 59
# YET
# 61
# 62
# YET
# 64
# GEN
# YET
# 67
# 68
# YET
# GEN
# 71
# YET
# 73
# 74
# YET
# 76
# 77
# YET
# 79
# GEN
# YET
# 82
# 83
# YET
# GEN
# 86
# YET
# 88
# 89
# YET
# 91
# 92
# YET
# 94
# GEN
# YET
# 97
# 98
# YET
# GEN
